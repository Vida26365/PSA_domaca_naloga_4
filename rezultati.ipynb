# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data.csv')

# %%
df[["avl_insert_ns",  "bentley_insert_ns"]].plot()

plt.show()

# %%
df[["avl_search_ns",  "bentley_search_ns"]].plot()
# Out:
# <Axes: >
